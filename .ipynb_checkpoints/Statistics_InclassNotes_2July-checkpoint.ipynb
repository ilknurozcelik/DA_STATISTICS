# %% [markdown]
# ## Statistics Session 6

# %% [markdown]
# İstatistik testler parametrik ve nonparametrik olarak ikiye ayrılır.
#
# Parametriik testler normal dağılım üzerine yapılır.
#
# Ortalama ve std sapma üzerine yapabildiğimiz testler parametrik testler ve en güçlü testlerdir.
#
# Normal dağılım olmadığında non-parametrik testleri uygulamak gerekir.

# %% [markdown]
# ## Independent Sample T Test
#
# İki bağımzsı grup olması gerekiyor
# Bir continous değişken olması gerekiyor
#
# İki farklı şekilde test statistiği hesaplanır:
# 1. İki grubun varyanslarının aynı olmadığı varsayımı ile
# 2. İki grubun da varyansının aynı olduğu varsayımı ile
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Dependent T Test

# %% [markdown]
# Aynı gözlemler üzerinden iki farklı ölçüm var. Örneklem grubumuzda aynı kişiler var ve bunlara bir program uyguayıp, bu uygulanan programın etkilerini istatistiksel olarak ortaya koymak için Dependent T test yapılır.

# %% [markdown]
# ## One-way ANOVA(ANalysis Of VAriance)

# %% [markdown]
# Continuous depentent variable olmalı
# Categorical independent variable olmalı (2 or more groups)
# Independent samples/groups
#
# TEST STATISTICS : burada F Test istatistiği hesaplanır.
#
# ANOVA Table : Python hesaplıyor
#
#
# ![image.png](attachment:image.png)
